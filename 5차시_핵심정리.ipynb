# %% [markdown]
# # 데이터 시각화(Matplotlib)
# #### 데이터 분서겡서 다루는 데이터는 매우 다양함
# #### 연속형(수치), 범주형, 문자열 ,시간, 날짜 등
# #### 데이터의 크기가 수천, 수만개가 넘기 때문에 데이터 시각화가 필요함
# #### 판다스 내장 시각화 메소드가 존재하지만 한계가 있음
# #### 시각화 전문도구(matplotlib)을 사용해서 원하는 형태의 그래프를 그려야함
#
# ## 선 그래프: 연속하는 데이터 값들을 직선 또는 곡선으로 연결한 그래프

# %%
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('연도별_매출액_현황.csv',header = 0) # 처음 행을 열의 이름 열거로 사용하겠다는 의미
df.head()
# Out:
#      연도      전체   일반통상  특수통상    국제특급     소포
# 0  2000  121895  15985  3210   71493  31207
# 1  2001  139339  14642  2786   88074  33837
# 2  2002  159195  15571  2862  106965  33797
# 3  2003  166897  15346  2453  119479  29619
# 4  2004  175071  15160  2384  131542  25985

# %%
data_total = df['전체'] 
print(data_total) #시리즈 형식 
plt.plot(data_total.index, data_total.values) # 평면그래프를 그리는데 index가 x축 값이 y축
# Out:
# 0     121895
# 1     139339
# 2     159195
# 3     166897
# 4     175071
# 5     187339
# 6     186396
# 7     197759
# 8     227008
# 9     268523
# 10    290052
# 11    324810
# 12    375593
# 13    395623
# 14    439748
# 15    492318
# 16    486186
# 17    402541
# 18    389447
# 19    394064
# Name: 전체, dtype: int64

# %% [markdown]
# ## 그래프 꾸미기
# #### matplotlib은 한글 폰트를 지원하지 않음

# %%
import matplotlib.pyplot as plt

plt.rc('font', family='NanumGothic') # For Windows
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
data_total = df['전체']
plt.figure(figsize=(10, 5))
plt.xticks(rotation = 'vertical')
plt.plot(data_total)

plt.title('매출 현황')
plt.xlabel('연도')
plt.ylabel('백만원')

plt.legend(labels=['전체'], loc='best')

plt.show()

# %%
data_total = df['전체']

plt.style.use('ggplot')

plt.figure(figsize=(10, 5))
plt.xticks(rotation = 'vertical')
plt.plot(data_total, marker='o', markersize=5)

plt.title('매출 현황', size=30)
plt.xlabel('연도', size=20)
plt.ylabel('백만원', size=20)

plt.legend(labels=['전체'], loc='best', fontsize=15)

plt.show()

# %%
for style in plt.style.available: #google matplotlib style, gallery
    print(style)
# Out:
# Solarize_Light2
# _classic_test_patch
# _mpl-gallery
# _mpl-gallery-nogrid
# bmh
# classic
# dark_background
# fast
# fivethirtyeight
# ggplot
# grayscale
# seaborn
# seaborn-bright
# seaborn-colorblind
# seaborn-dark
# seaborn-dark-palette
# seaborn-darkgrid
# seaborn-deep
# seaborn-muted
# seaborn-notebook
# seaborn-paper
# seaborn-pastel
# seaborn-poster
# seaborn-talk
# seaborn-ticks
# seaborn-white
# seaborn-whitegrid
# tableau-colorblind10

# %%
data_total = df['전체']
data_general = df['일반통상']

plt.style.use('ggplot')

fig = plt.figure(figsize=(10, 10)) #모든 그래프가 들어갈 전체 크기
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2) #2개의 그래프이고 위1 아래1 구조이니까 전체 구조는 2x1 행렬 구조 그 중 2번째 위치하겠다 
ax1.plot(data_total, marker='o', markersize=10, label='전체')
ax2.plot(data_general, marker='o', markerfacecolor='green', markersize=10,
         color='green', linewidth=2, label='일반통상')

ax1.legend(loc='best')
ax2.legend(loc='best')

ax1.set_ylim(0, 600000)
ax2.set_ylim(5000, 40000)

ax1.set_xticklabels(data_total.index, rotation=60)
ax2.set_xticklabels(data_general.index, rotation=60)

plt.show()
# Out:
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\1209527574.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(data_total.index, rotation=60)
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\1209527574.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(data_general.index, rotation=60)

# %%
plt.style.use('ggplot') #1. 스타일 지정 

fig = plt.figure(figsize=(16, 10)) #그래프가 들어갈 전체 크기 지정 
#그래프4개 따로 -> 객체 4개 지정해야함, 위치와 함께
ax1 = fig.add_subplot(2,2,1)  
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

#각 그래프 x축 y축, 기타 세팅들 
ax1.plot(df.index, df['전체'], marker='o', markersize=5, linewidth=2) 
ax2.plot(df.index, df['일반통상'], marker='o', markersize=5, linewidth=2)
ax3.plot(df.index, df['국제특급'], marker='o', markersize=5, linewidth=2)
ax4.plot(df.index, df['소포'], marker='o', markersize=5, linewidth=2)

#각 그래프 제목 
ax1.set_title('전체')
ax2.set_title('일반통상')
ax3.set_title('국제특급')
ax4.set_title('소포')

#각 그래프 x축 각도
ax1.set_xticklabels(df.index, rotation=90)
ax2.set_xticklabels(df.index, rotation=90)
ax3.set_xticklabels(df.index, rotation=90)
ax4.set_xticklabels(df.index, rotation=90)

plt.show()
# Out:
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\523230051.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df.index, rotation=90)
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\523230051.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(df.index, rotation=90)
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\523230051.py:21: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax3.set_xticklabels(df.index, rotation=90)
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\523230051.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax4.set_xticklabels(df.index, rotation=90)

# %%
#한 공간에 여러개의 그래프를 그릴 때
plt.style.use('ggplot')

fig = plt.figure(figsize=(8, 5)) #전체 사이즈
ax = fig.add_subplot(1,1,1) #객체 한개만 생성함 

#한 객체에 대해 여러 설정을 한다음 
ax.plot(df.index, df['전체'], marker='o', markersize=10, linewidth=2, label='전체')
ax.plot(df.index, df['소포'], marker='o', markersize=10, linewidth=2, label='소포')
ax.plot(df.index, df['국제특급'], marker='o', markersize=10, linewidth=2, label='국제특급')
ax.legend(loc='best') #범주를 올바른 위치에 위치시키고 

ax.set_title('항목별 매출 현황', size=20)
ax.set_xlabel('연도', size=10)
ax.set_ylabel('백만원', size=10)

ax.set_ylim(0, 600000)

ax.set_xticklabels(df.index, rotation=60)

plt.show()
# Out:
# C:\Users\swlee\AppData\Local\Temp\ipykernel_10960\2791267959.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(df.index, rotation=60)

# %%
df_3 = df[['일반통상', '특수통상', '소포']]

df_3.plot(kind='area', stacked=False, alpha=0.2, figsize=(10, 5))
#중첩을 하지 않겠다, alpha 투명도 

plt.title('항목별 매출 현황', size=20)
plt.xlabel('연도', size=10)
plt.ylabel('백만원', size=10)
plt.legend(loc='best')

plt.show()

# %%
df_3 = df[['일반통상', '특수통상', '소포']]

df_3.plot(kind='area', stacked=True, alpha=0.2, figsize=(10, 5))
#중첩 사용 
#각각의 y값은 면적사이의 값이 되고 경계선은 중첩값을 의미한다 
plt.title('항목별 매출 현황', size=20)
plt.xlabel('연도', size=10)
plt.ylabel('백만원', size=10)
plt.legend(loc='best')

plt.show()

# %%
df_3 = df[['일반통상', '특수통상', '소포']]

df_3.plot(kind='bar', width=1.0, color=['orange','green','red'], figsize=(10, 5))

plt.title('항목별 매출 현황', size=20)
plt.xlabel('연도', size=10)
plt.ylabel('백만원', size=10)
plt.legend(loc='best')

plt.show()

# %%
#먼저 합계를 구하고 오름차순으로 정렬을 한 데이터프레임을 만들고 
df_sum = df.sum(axis=0)
df_sum = df_sum.sort_values(ascending=True)
print(df_sum)
# Out:
# 연도        40190
# 특수통상     299319
# 일반통상     362182
# 소포       499913
# 국제특급    4658389
# 전체      5819804
# dtype: int64

# %%
df_sum.plot(kind='barh', width=0.5, color='blue', figsize=(8, 4))

plt.title('항목별 매출 합계', size=20)
plt.xlabel('백만원', size=10)
plt.ylabel('항목', size=10)

plt.show()

# %% [markdown]
# # 기타 그래프
# #### 히스토그램, 산점도, 파이차트, 박스플롯
# #### 히스토그램 : 범위에 따른 빈도수
# #### 산점도 : 2개(3개)데이터 간의 상관관계 (증증 감감 증감 ... )
# #### 파이차트 : 한개의 열의 데이터 빈도수를 시각화
# #### 여러개(또는 하나)의 열의 데이터의 최대,최소,중간,1분위,3분위 값을 시각화 해서 표현함.  산포도도 알수 있음.
# #### 용도에 맞게 골라서 복붙해서 사용하자.
